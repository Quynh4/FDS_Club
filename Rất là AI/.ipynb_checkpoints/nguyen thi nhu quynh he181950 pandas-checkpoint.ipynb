# %%
import pandas as pd
import numpy as np

# %%
# đọc file Building_Permits
# lưu ý vì do code offline nên khi tải file về thì phải chọn đúng đường dẫn.
# có thể tự đặt tên biến tuỳ thích

# %%
df = pd.read_csv('D:\Building_Permits.csv')
df.head(5)
# Out:
# C:\Users\NITRO 5\AppData\Local\Temp\ipykernel_4512\3592621272.py:1: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('D:\Building_Permits.csv')
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
# 4           11/28/2016  0342  001            950                  NaN
#
#   Street Name Street Suffix  ...  Existing Construction Type  \
# 0       Ellis            St  ...                         3.0
# 1       Geary            St  ...                         3.0
# 2     Pacific            Av  ...                         1.0
# 3     Pacific            Av  ...                         5.0
# 4      Market            St  ...                         3.0
#
#   Existing Construction Type Description Proposed Construction Type  \
# 0                          constr type 3                        NaN
# 1                          constr type 3                        NaN
# 2                          constr type 1                        1.0
# 3                         wood frame (5)                        5.0
# 4                          constr type 3                        NaN
#
#   Proposed Construction Type Description Site Permit Supervisor District  \
# 0                                    NaN         NaN                 3.0
# 1                                    NaN         NaN                 3.0
# 2                          constr type 1         NaN                 3.0
# 3                         wood frame (5)         NaN                 3.0
# 4                                    NaN         NaN                 6.0
#
#   Neighborhoods - Analysis Boundaries  Zipcode  \
# 0                          Tenderloin  94102.0
# 1                          Tenderloin  94102.0
# 2                        Russian Hill  94109.0
# 3                            Nob Hill  94109.0
# 4                          Tenderloin  94102.0
#
#                                     Location      Record ID
# 0  (37.785719256680785, -122.40852313194863)  1380611233945
# 1   (37.78733980600732, -122.41063199757738)  1420164406718
# 2    (37.7946573324287, -122.42232562979227)  1424856504716
# 3   (37.79595867909168, -122.41557405519474)  1443574295566
# 4   (37.78315261897309, -122.40950883997789)   144548169992
#
# [5 rows x 43 columns]

# %%
df1 = pd.DataFrame({'Môn học': ["PFP", 'PRO', 'PRF', 'DBI', 'MAE', 'MAD', 'MAS', 'MAI'],
                    'Mentor': ['Trần An', 'Tuấn Anh', 'Nghĩa', 'Tony', 'Tony', 'Hoàng', 'Dũng', 'Cường']})
df2 = pd.DataFrame({'Môn học': ["PFP", 'PRO', 'PRF', 'DBI', 'MAE', 'MAD', 'MAS', 'MAI'],
                    'Thời gian training': ['Tối thứ 4 15/03', 'Tối thứ 5 16/03', 'Tối thứ năm 16/03', 'Tối thứ 4 15/03','','Thứ 4 22/03','','T4,5,6']})

# %% [markdown]
# # Q1: gộp 2 cái dataframe lại thành một dataframe với tên gọi là 'df' sao cho df có dạng
# |   | mon hoc | mentor   | thoi gian trainning |
# |---|---------|----------|---------------------|
# | 0 | PFP     | Trần An  | Tối thứ 4 15/03     |
# | 1 | PRO     | Tuấn Anh | Tối thứ 5 16/03     |
# | 2 | PRF     | Nghĩa    | Tối thứ năm 16/03   |
# | 3 | DBI     | Tony     | Tối thứ 4 15/03     |
# | 4 | MAE     | Tony     |                     |
# | 5 | MAD     | Hoàng    | Thứ 4 22/03         |
# | 6 | MAS     | Dũng     |                     |
# | 7 | MAI     | Cường    | T4,5,6              |

# %%
#code your Q1 here :>

df = pd.concat([df1,df2])

# %% [markdown]
# # Q2: giờ thì đưa df đó thành csv với tên file là 'lịch dạy thêm demo.csv'

# %%
#code your Q2 here :>

df.to_csv('lịch dạy thêm demo.csv')
pd.read_csv('lịch dạy thêm demo.csv')
# Out:
#      Unnamed: 0  School_ID                                     NAME_OF_SCHOOL  \
# 0             0     610038                  Abraham Lincoln Elementary School
# 1             1     610281  Adam Clayton Powell Paideia Community Academy ...
# 2             2     610185                Adlai E Stevenson Elementary School
# 3             3     609993                    Agustin Lara Elementary Academy
# 4             4     610513                      Air Force Academy High School
# ..          ...        ...                                                ...
# 561         561     610172                William T Sherman Elementary School
# 562         562     609844                 William W Carter Elementary School
# 563         563     610088                Wolfgang A Mozart Elementary School
# 564         564     609977               Woodlawn Community Elementary School
# 565         565     610392                 World Language Academy High School
#
#     Elementary, Middle, or High School         Street_Address     City State  \
# 0                                   ES        615 W Kemper Pl  Chicago    IL
# 1                                   ES  7511 S South Shore Dr  Chicago    IL
# 2                                   ES     8010 S Kostner Ave  Chicago    IL
# 3                                   ES     4619 S Wolcott Ave  Chicago    IL
# 4                                   HS        3630 S Wells St  Chicago    IL
# ..                                 ...                    ...      ...   ...
# 561                                 ES         1000 W 52nd St  Chicago    IL
# 562                                 ES    5740 S Michigan Ave  Chicago    IL
# 563                                 ES      2200 N Hamlin Ave  Chicago    IL
# 564                                 ES     6657 S Kimbark Ave  Chicago    IL
# 565                                 HS     3120 S Kostner Ave  Chicago    IL
#
#      ZIP_Code    Phone_Number  \
# 0       60614  (773) 534-5720
# 1       60649  (773) 535-6650
# 2       60652  (773) 535-2280
# 3       60609  (773) 535-4389
# 4       60609  (773) 535-1590
# ..        ...             ...
# 561     60609  (773) 535-1757
# 562     60637  (773) 535-0860
# 563     60647  (773) 534-4160
# 564     60637  (773) 535-0801
# 565     60623  (773) 535-4334
#
#                                                   Link  ...  \
# 0    http://schoolreports.cps.edu/SchoolProgressRep...  ...
# 1    http://schoolreports.cps.edu/SchoolProgressRep...  ...
# 2    http://schoolreports.cps.edu/SchoolProgressRep...  ...
# 3    http://schoolreports.cps.edu/SchoolProgressRep...  ...
# 4    http://schoolreports.cps.edu/SchoolProgressRep...  ...
# ..                                                 ...  ...
# 561  http://schoolreports.cps.edu/SchoolProgressRep...  ...
# 562  http://schoolreports.cps.edu/SchoolProgressRep...  ...
# 563  http://schoolreports.cps.edu/SchoolProgressRep...  ...
# 564  http://schoolreports.cps.edu/SchoolProgressRep...  ...
# 565  http://schoolreports.cps.edu/SchoolProgressRep...  ...
#
#     Freshman_on_Track_Rate__ X_COORDINATE Y_COORDINATE   Latitude  Longitude  \
# 0                        NDA  1171699.458  1915829.428  41.924497 -87.644522
# 1                        NDA  1196129.985  1856209.466  41.760324 -87.556736
# 2                        NDA  1148427.165  1851012.215  41.747111 -87.731702
# 3                        NDA  1164504.290  1873959.199  41.809757 -87.672145
# 4                       91.8  1175177.622  1880745.126  41.828146 -87.632794
# ..                       ...          ...          ...        ...        ...
# 561                      NDA  1170500.817  1870373.159  41.799788 -87.650255
# 562                      NDA  1178101.365  1866810.123  41.789841 -87.622490
# 563                      NDA  1150644.396  1914368.955  41.920927 -87.721925
# 564                      NDA  1185825.188  1860883.579  41.773400 -87.594356
# 565                       76  1147521.302  1883405.128  41.836020 -87.734195
#
#     COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME Ward  Police_District  \
# 0                       7        LINCOLN PARK   43               18
# 1                      43         SOUTH SHORE    7                4
# 2                      70             ASHBURN   13                8
# 3                      61            NEW CITY   20                9
# 4                      34       ARMOUR SQUARE   11                9
# ..                    ...                 ...  ...              ...
# 561                    61            NEW CITY   16                9
# 562                    40     WASHINGTON PARK   20                2
# 563                    22        LOGAN SQUARE   35               25
# 564                    42            WOODLAWN    5                3
# 565                    30      SOUTH LAWNDALE   22               10
#
#                         Location
# 0    (41.92449696, -87.64452163)
# 1    (41.76032435, -87.55673627)
# 2    (41.74711093, -87.73170248)
# 3      (41.8097569, -87.6721446)
# 4    (41.82814609, -87.63279369)
# ..                           ...
# 561  (41.79978772, -87.65025483)
# 562  (41.78984129, -87.62248974)
# 563  (41.92092734, -87.72192541)
# 564  (41.77339962, -87.59435584)
# 565  (41.83601953, -87.73419465)
#
# [566 rows x 79 columns]

# %% [markdown]
# # Q3: nhập file 'ChicagoPublicSchools.csv' rồi dùng hàm iloc để lấy được Tên trường 'Abraham Lincoln Elementary School'

# %%
# code your Q3 here :>

df = pd.read_csv('D:\ChicagoPublicSchools.csv')
df.iloc[df.NAME_OF_SCHOOL == 'Abraham Lincoln Elementary School']
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[34], line 4
#       1 # code your Q3 here :>
#       3 df = pd.read_csv('D:\ChicagoPublicSchools.csv')
# ----> 4 df.iloc[df.NAME_OF_SCHOOL == 'Abraham Lincoln Elementary School']
#
# File D:\New folder\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File D:\New folder\lib\site-packages\pandas\core\indexing.py:1611, in _iLocIndexer._getitem_axis(self, key, axis)
#    1608     key = np.asarray(key)
#    1610 if com.is_bool_indexer(key):
# -> 1611     self._validate_key(key, axis)
#    1612     return self._getbool_axis(key, axis=axis)
#    1614 # a list of integers
#
# File D:\New folder\lib\site-packages\pandas\core\indexing.py:1452, in _iLocIndexer._validate_key(self, key, axis)
#    1450 if hasattr(key, "index") and isinstance(key.index, Index):
#    1451     if key.index.inferred_type == "integer":
# -> 1452         raise NotImplementedError(
#    1453             "iLocation based boolean "
#    1454             "indexing on an integer type "
#    1455             "is not available"
#    1456         )
#    1457     raise ValueError(
#    1458         "iLocation based boolean indexing cannot use "
#    1459         "an indexable as a mask"
#    1460     )
#    1461 return
#
# NotImplementedError: iLocation based boolean indexing on an integer type is not available

# %% [markdown]
# # Q3.1: tiếp tục dùng hàm iloc để lấy được 5 hàng đầu tiên

# %%
# code your Q3.1 here :>
df.iloc[:5]
# Out:
#    School_ID                                     NAME_OF_SCHOOL  \
# 0     610038                  Abraham Lincoln Elementary School
# 1     610281  Adam Clayton Powell Paideia Community Academy ...
# 2     610185                Adlai E Stevenson Elementary School
# 3     609993                    Agustin Lara Elementary Academy
# 4     610513                      Air Force Academy High School
#
#   Elementary, Middle, or High School         Street_Address     City State  \
# 0                                 ES        615 W Kemper Pl  Chicago    IL
# 1                                 ES  7511 S South Shore Dr  Chicago    IL
# 2                                 ES     8010 S Kostner Ave  Chicago    IL
# 3                                 ES     4619 S Wolcott Ave  Chicago    IL
# 4                                 HS        3630 S Wells St  Chicago    IL
#
#    ZIP_Code    Phone_Number  \
# 0     60614  (773) 534-5720
# 1     60649  (773) 535-6650
# 2     60652  (773) 535-2280
# 3     60609  (773) 535-4389
# 4     60609  (773) 535-1590
#
#                                                 Link  \
# 0  http://schoolreports.cps.edu/SchoolProgressRep...
# 1  http://schoolreports.cps.edu/SchoolProgressRep...
# 2  http://schoolreports.cps.edu/SchoolProgressRep...
# 3  http://schoolreports.cps.edu/SchoolProgressRep...
# 4  http://schoolreports.cps.edu/SchoolProgressRep...
#
#                       Network_Manager  ... Freshman_on_Track_Rate__  \
# 0        Fullerton Elementary Network  ...                      NDA
# 1           Skyway Elementary Network  ...                      NDA
# 2           Midway Elementary Network  ...                      NDA
# 3         Pershing Elementary Network  ...                      NDA
# 4  Southwest Side High School Network  ...                     91.8
#
#   X_COORDINATE Y_COORDINATE   Latitude  Longitude COMMUNITY_AREA_NUMBER  \
# 0  1171699.458  1915829.428  41.924497 -87.644522                     7
# 1  1196129.985  1856209.466  41.760324 -87.556736                    43
# 2  1148427.165  1851012.215  41.747111 -87.731702                    70
# 3  1164504.290  1873959.199  41.809757 -87.672145                    61
# 4  1175177.622  1880745.126  41.828146 -87.632794                    34
#
#   COMMUNITY_AREA_NAME  Ward Police_District                     Location
# 0        LINCOLN PARK    43              18  (41.92449696, -87.64452163)
# 1         SOUTH SHORE     7               4  (41.76032435, -87.55673627)
# 2             ASHBURN    13               8  (41.74711093, -87.73170248)
# 3            NEW CITY    20               9    (41.8097569, -87.6721446)
# 4       ARMOUR SQUARE    11               9  (41.82814609, -87.63279369)
#
# [5 rows x 78 columns]

# %% [markdown]
# #Q3.2 dùng hàm loc để lấy được Tên trường 'Abraham Lincoln Elementary School'

# %%
# code your Q3.2 here :>

df.loc[df["NAME_OF_SCHOOL"] == 'Abraham Lincoln Elementary School']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\New folder\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File D:\New folder\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\New folder\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'NAME_OF_SCHOOL'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 3
#       1 # code your Q3.2 here :>
# ----> 3 df.loc[df["NAME_OF_SCHOOL"] == 'Abraham Lincoln Elementary School']
#
# File D:\New folder\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File D:\New folder\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'NAME_OF_SCHOOL'

# %% [markdown]
# Q3.3 giờ tiếp tục dùng hàm loc để lấy được 5 hàng đầu

# %%
# code your Q3.3 here :>
df.loc[:4]
# Out:
#    School_ID                                     NAME_OF_SCHOOL  \
# 0     610038                  Abraham Lincoln Elementary School
# 1     610281  Adam Clayton Powell Paideia Community Academy ...
# 2     610185                Adlai E Stevenson Elementary School
# 3     609993                    Agustin Lara Elementary Academy
# 4     610513                      Air Force Academy High School
#
#   Elementary, Middle, or High School         Street_Address     City State  \
# 0                                 ES        615 W Kemper Pl  Chicago    IL
# 1                                 ES  7511 S South Shore Dr  Chicago    IL
# 2                                 ES     8010 S Kostner Ave  Chicago    IL
# 3                                 ES     4619 S Wolcott Ave  Chicago    IL
# 4                                 HS        3630 S Wells St  Chicago    IL
#
#    ZIP_Code    Phone_Number  \
# 0     60614  (773) 534-5720
# 1     60649  (773) 535-6650
# 2     60652  (773) 535-2280
# 3     60609  (773) 535-4389
# 4     60609  (773) 535-1590
#
#                                                 Link  \
# 0  http://schoolreports.cps.edu/SchoolProgressRep...
# 1  http://schoolreports.cps.edu/SchoolProgressRep...
# 2  http://schoolreports.cps.edu/SchoolProgressRep...
# 3  http://schoolreports.cps.edu/SchoolProgressRep...
# 4  http://schoolreports.cps.edu/SchoolProgressRep...
#
#                       Network_Manager  ... Freshman_on_Track_Rate__  \
# 0        Fullerton Elementary Network  ...                      NDA
# 1           Skyway Elementary Network  ...                      NDA
# 2           Midway Elementary Network  ...                      NDA
# 3         Pershing Elementary Network  ...                      NDA
# 4  Southwest Side High School Network  ...                     91.8
#
#   X_COORDINATE Y_COORDINATE   Latitude  Longitude COMMUNITY_AREA_NUMBER  \
# 0  1171699.458  1915829.428  41.924497 -87.644522                     7
# 1  1196129.985  1856209.466  41.760324 -87.556736                    43
# 2  1148427.165  1851012.215  41.747111 -87.731702                    70
# 3  1164504.290  1873959.199  41.809757 -87.672145                    61
# 4  1175177.622  1880745.126  41.828146 -87.632794                    34
#
#   COMMUNITY_AREA_NAME  Ward Police_District                     Location
# 0        LINCOLN PARK    43              18  (41.92449696, -87.64452163)
# 1         SOUTH SHORE     7               4  (41.76032435, -87.55673627)
# 2             ASHBURN    13               8  (41.74711093, -87.73170248)
# 3            NEW CITY    20               9    (41.8097569, -87.6721446)
# 4       ARMOUR SQUARE    11               9  (41.82814609, -87.63279369)
#
# [5 rows x 78 columns]

# %% [markdown]
# # Tìm tổng số missing value

# %%
# lấy số điểm dữ liệu bị thiếu trên mỗi cột

# Tính tổng số missing value
total_cells = np.product(#code tại đây) #
total_missing = 
# Hiển thị total_cels và total_missing
print(#code tại đây)

# %% [markdown]
# ![Screenshot 2023-04-01 032320.png](data:image/png;base64,...)

# %% [markdown]
# # Drop missinng value theo Rows

# %%
# Tạo 1 bản sao DataFrame mới rồi drop trong bản sao. Không drop trực tiếp lên DataFrame gốc

# %% [markdown]
# # Drop missing value theo Columns

# %%
df_with_na_dropped = #code ở đây

# So sánh số lượng cột đã xoá
cols_in_original_dataset = 
print(cols_in_original_dataset) # số cột ban đầu
cols_in_na_dropped = 
print(cols_in_na_dropped) # số cột còn lại
dropped_columns = 
print(dropped_columns) # số cột đã xoá

# %% [markdown]
# ![Screenshot 2023-04-01 034519.png](data:image/png;base64,...)

# %% [markdown]
# # Thay thế các giá trị NaN bằng giá trị 0

# %%
df_with_na_imputed =  #code ở đây
