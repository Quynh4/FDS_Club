# %%
from numpy import loadtxt
from keras import Sequential
from keras.models import load_model
from keras.models import save_model
from keras.layers import Dense
from sklearn.model_selection import train_test_split
data = loadtxt('data.csv', delimiter=',')
data
# Out:
# array([[  6.   , 148.   ,  72.   , ...,   0.627,  50.   ,   1.   ],
#        [  1.   ,  85.   ,  66.   , ...,   0.351,  31.   ,   0.   ],
#        [  8.   , 183.   ,  64.   , ...,   0.672,  32.   ,   1.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,   0.245,  30.   ,   0.   ],
#        [  1.   , 126.   ,  60.   , ...,   0.349,  47.   ,   1.   ],
#        [  1.   ,  93.   ,  70.   , ...,   0.315,  23.   ,   0.   ]])

# %%
X = data[:,0:8]
y = data[:,8]

# %%
X_train_val, X_test, y_train_val, y_test = train_test_split(x, y, test_size=0.2)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.2)

model = Sequential()
model.add(Dense(16, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_9 (Dense)             (None, 16)                144
#
#  dense_10 (Dense)            (None, 8)                 136
#
#  dense_11 (Dense)            (None, 1)                 9
#
# ...
# Total params: 289
# Trainable params: 289
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=188, batch_size=8, validation_data=(X_val,y_val))
# Out:
# Epoch 1/188
# 62/62 [==============================] - 1s 3ms/step - loss: 10.9690 - accuracy: 0.6741 - val_loss: 4.7468 - val_accuracy: 0.6260
# Epoch 2/188
# 62/62 [==============================] - 0s 1ms/step - loss: 2.0134 - accuracy: 0.6049 - val_loss: 0.7945 - val_accuracy: 0.5447
# Epoch 3/188
# 62/62 [==============================] - 0s 1ms/step - loss: 0.7192 - accuracy: 0.5540 - val_loss: 0.7296 - val_accuracy: 0.5285
# Epoch 4/188
# 62/62 [==============================] - 0s 1ms/step - loss: 0.6897 - accuracy: 0.5173 - val_loss: 0.7007 - val_accuracy: 0.5366
# Epoch 5/188
# 62/62 [==============================] - 0s 1ms/step - loss: 0.6746 - accuracy: 0.5479 - val_loss: 0.6950 - val_accuracy: 0.5447
# Epoch 6/188
# 62/62 [==============================] - 0s 1ms/step - loss: 0.6653 - accuracy: 0.5479 - val_loss: 0.6839 - val_accuracy: 0.5610
# Epoch 7/188
# ...

# %% [markdown]
# model.save('my_model.h5')
# model = load_model('mymodel.h5')
#
# import codecs
#
# with codecs.open('mymodel.h5', 'r', encoding='utf-8', errors='ignore') as f:
#     model = f.read()
# model = load_model('mymodel.h5')
# # Re-save the model with a new filename
# save_model(model, 'mymodel_new.h5')
#
# # Load the model from the new file
# model_new = load_model('mymodel_new.h5')

# %%
loss, acc = model.evaluate(X_test, y_test)
print("Loss = ", loss)
print("Acc = ", acc)
# Out:
# 5/5 [==============================] - 0s 1ms/step - loss: 0.7743 - accuracy: 0.6234
# Loss =  0.7743420004844666
# Acc =  0.6233766078948975

# %%
import numpy
X_new = X_test[10]
y_new = y_test[10]
X_new = numpy.expand_dims (X_new, axis=0)
y_predict = model.predict(X_new)
result = "Tiểu đường (1)"
if y_predict <= 0.5:
    result = "Không tiểu đường"
print("Gia tri du doan = ", result)
print("Gia tri đung la = ", y_new)
# Out:
# 1/1 [==============================] - 0s 15ms/step
# Gia tri du doan =  Không tiểu đường
# Gia tri đung la =  0.0
